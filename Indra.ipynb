# %%
import pandas as pd

# %%
data = pd.read_csv('vgchartz-2024.csv')

# %%
data.head()
# Out:
#                                              img                        title  \
# 0  /games/boxart/full_6510540AmericaFrontccc.jpg           Grand Theft Auto V
# 1  /games/boxart/full_5563178AmericaFrontccc.jpg           Grand Theft Auto V
# 2                    /games/boxart/827563ccc.jpg  Grand Theft Auto: Vice City
# 3  /games/boxart/full_9218923AmericaFrontccc.jpg           Grand Theft Auto V
# 4  /games/boxart/full_4990510AmericaFrontccc.jpg    Call of Duty: Black Ops 3
#
#   console    genre       publisher       developer  critic_score  na_sales  \
# 0     PS3   Action  Rockstar Games  Rockstar North           9.4      6.37
# 1     PS4   Action  Rockstar Games  Rockstar North           9.7      6.06
# 2     PS2   Action  Rockstar Games  Rockstar North           9.6      8.41
# 3    X360   Action  Rockstar Games  Rockstar North           NaN      9.06
# 4     PS4  Shooter      Activision        Treyarch           8.1      6.18
#
#    jp_sales  pal_sales  other_sales release_date last_update
# 0      0.99       9.85         3.12   2013-09-17         NaN
# 1      0.60       9.71         3.02   2014-11-18  2018-01-03
# 2      0.47       5.49         1.78   2002-10-28         NaN
# 3      0.06       5.33         1.42   2013-09-17         NaN
# 4      0.41       6.05         2.44   2015-11-06  2018-01-14

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64016 entries, 0 to 64015
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   img           64016 non-null  object
#  1   title         64016 non-null  object
#  2   console       64016 non-null  object
#  3   genre         64016 non-null  object
#  4   publisher     64016 non-null  object
#  5   developer     63999 non-null  object
#  6   critic_score  6678 non-null   float64
#  7   na_sales      12637 non-null  float64
#  8   jp_sales      6726 non-null   float64
#  9   pal_sales     12824 non-null  float64
#  10  other_sales   15128 non-null  float64
#  11  release_date  56965 non-null  object
#  12  last_update   17879 non-null  object
# dtypes: float64(5), object(8)
# memory usage: 6.3+ MB

# %%
data.describe()
# Out:
#        critic_score      na_sales     jp_sales     pal_sales   other_sales
# count   6678.000000  12637.000000  6726.000000  12824.000000  15128.000000
# mean       7.220440      0.264740     0.102281      0.149472      0.043041
# std        1.457066      0.494787     0.168811      0.392653      0.126643
# min        1.000000      0.000000     0.000000      0.000000      0.000000
# 25%        6.400000      0.050000     0.020000      0.010000      0.000000
# 50%        7.500000      0.120000     0.040000      0.040000      0.010000
# 75%        8.300000      0.280000     0.120000      0.140000      0.030000
# max       10.000000      9.760000     2.130000      9.850000      3.120000

# %%
data.head(10)
# Out:
#                                                  img  \
# 0      /games/boxart/full_6510540AmericaFrontccc.jpg
# 1      /games/boxart/full_5563178AmericaFrontccc.jpg
# 2                        /games/boxart/827563ccc.jpg
# 3      /games/boxart/full_9218923AmericaFrontccc.jpg
# 4      /games/boxart/full_4990510AmericaFrontccc.jpg
# 5  /games/boxart/full_call-of-duty-modern-warfare...
# 6  /games/boxart/full_call-of-duty-black-ops_5Ame...
# 7      /games/boxart/full_4653215AmericaFrontccc.jpg
# 8      /games/boxart/full_1977964AmericaFrontccc.jpg
# 9      /games/boxart/full_4649679AmericaFrontccc.png
#
#                             title console             genre       publisher  \
# 0              Grand Theft Auto V     PS3            Action  Rockstar Games
# 1              Grand Theft Auto V     PS4            Action  Rockstar Games
# 2     Grand Theft Auto: Vice City     PS2            Action  Rockstar Games
# 3              Grand Theft Auto V    X360            Action  Rockstar Games
# 4       Call of Duty: Black Ops 3     PS4           Shooter      Activision
# 5  Call of Duty: Modern Warfare 3    X360           Shooter      Activision
# 6         Call of Duty: Black Ops    X360           Shooter      Activision
# 7           Red Dead Redemption 2     PS4  Action-Adventure  Rockstar Games
# 8      Call of Duty: Black Ops II    X360           Shooter      Activision
# 9      Call of Duty: Black Ops II     PS3           Shooter      Activision
#
#         developer  critic_score  na_sales  jp_sales  pal_sales  other_sales  \
# 0  Rockstar North           9.4      6.37      0.99       9.85         3.12
# 1  Rockstar North           9.7      6.06      0.60       9.71         3.02
# 2  Rockstar North           9.6      8.41      0.47       5.49         1.78
# 3  Rockstar North           NaN      9.06      0.06       5.33         1.42
# 4        Treyarch           8.1      6.18      0.41       6.05         2.44
# 5   Infinity Ward           8.7      9.07      0.13       4.29         1.33
# 6        Treyarch           8.8      9.76      0.11       3.73         1.14
# 7  Rockstar Games           9.8      5.26      0.21       6.21         2.26
# 8        Treyarch           8.4      8.27      0.07       4.32         1.20
# 9        Treyarch           8.0      4.99      0.65       5.88         2.28
#
#   release_date last_update
# 0   2013-09-17         NaN
# 1   2014-11-18  2018-01-03
# 2   2002-10-28         NaN
# 3   2013-09-17         NaN
# 4   2015-11-06  2018-01-14
# 5   2011-11-08         NaN
# 6   2010-11-09         NaN
# 7   2018-10-26  2018-11-02
# 8   2012-11-13  2018-04-07
# 9   2012-11-13  2018-04-07

# %%
isnull() is used to identify or detect the missing values in the data frame.

# %%
data.isnull()
# Out:
#          img  title  console  genre  publisher  developer  critic_score  \
# 0      False  False    False  False      False      False         False
# 1      False  False    False  False      False      False         False
# 2      False  False    False  False      False      False         False
# 3      False  False    False  False      False      False          True
# 4      False  False    False  False      False      False         False
# ...      ...    ...      ...    ...        ...        ...           ...
# 64011  False  False    False  False      False      False          True
# 64012  False  False    False  False      False      False          True
# 64013  False  False    False  False      False      False          True
# 64014  False  False    False  False      False      False          True
# 64015  False  False    False  False      False      False          True
#
#        na_sales  jp_sales  pal_sales  other_sales  release_date  last_update
# 0         False     False      False        False         False         True
# 1         False     False      False        False         False        False
# 2         False     False      False        False         False         True
# 3         False     False      False        False         False         True
# 4         False     False      False        False         False        False
# ...         ...       ...        ...          ...           ...          ...
# 64011      True      True       True         True         False        False
# 64012      True      True       True         True         False        False
# 64013      True      True       True         True         False        False
# 64014      True      True       True         True         False        False
# 64015      True      True       True         True          True        False
#
# [64016 rows x 13 columns]

# %%
dropna() returns a new DataFrame object with rows or columns removed if they contain NA values.

# %%
data.dropna()
# Out:
#                                                  img  \
# 1      /games/boxart/full_5563178AmericaFrontccc.jpg
# 4      /games/boxart/full_4990510AmericaFrontccc.jpg
# 7      /games/boxart/full_4653215AmericaFrontccc.jpg
# 8      /games/boxart/full_1977964AmericaFrontccc.jpg
# 9      /games/boxart/full_4649679AmericaFrontccc.png
# ...                                              ...
# 11794  /games/boxart/full_2874583AmericaFrontccc.jpg
# 11920  /games/boxart/full_4489495AmericaFrontccc.jpg
# 12216  /games/boxart/full_5524695AmericaFrontccc.jpg
# 13198  /games/boxart/full_5198003AmericaFrontccc.jpg
# 15044      /games/boxart/full_8777680PALFrontccc.png
#
#                               title console             genre  \
# 1                Grand Theft Auto V     PS4            Action
# 4         Call of Duty: Black Ops 3     PS4           Shooter
# 7             Red Dead Redemption 2     PS4  Action-Adventure
# 8        Call of Duty: Black Ops II    X360           Shooter
# 9        Call of Duty: Black Ops II     PS3           Shooter
# ...                             ...     ...               ...
# 11794                RPG Maker: Fes     3DS      Role-Playing
# 11920    BlazBlue: Cross Tag Battle      NS          Fighting
# 12216            Disgaea 1 Complete      NS      Role-Playing
# 13198                  GrimGrimoire     PS2          Strategy
# 15044  Tenkai Knights: Brave Battle     3DS            Action
#
#                 publisher             developer  critic_score  na_sales  \
# 1          Rockstar Games        Rockstar North           9.7      6.06
# 4              Activision              Treyarch           8.1      6.18
# 7          Rockstar Games        Rockstar Games           9.8      5.26
# 8              Activision              Treyarch           8.4      8.27
# 9              Activision              Treyarch           8.0      4.99
# ...                   ...                   ...           ...       ...
# 11794         NIS America        Kadokawa Games           7.0      0.03
# 11920    Arc System Works      Arc System Works           8.0      0.04
# 12216         NIS America  Nippon Ichi Software           8.0      0.03
# 13198         NIS America           Vanillaware           7.7      0.01
# 15044  Namco Bandai Games         Delta Factory           4.5      0.01
#
#        jp_sales  pal_sales  other_sales release_date last_update
# 1          0.60       9.71         3.02   2014-11-18  2018-01-03
# 4          0.41       6.05         2.44   2015-11-06  2018-01-14
# 7          0.21       6.21         2.26   2018-10-26  2018-11-02
# 8          0.07       4.32         1.20   2012-11-13  2018-04-07
# 9          0.65       5.88         2.28   2012-11-13  2018-04-07
# ...         ...        ...          ...          ...         ...
# 11794      0.02       0.00         0.00   2017-06-27  2018-04-22
# 11920      0.01       0.01         0.01   2018-06-05  2018-06-06
# 12216      0.01       0.01         0.00   2018-10-09  2019-02-19
# 13198      0.03       0.01         0.00   2007-06-26  2019-01-10
# 15044      0.00       0.01         0.00   2014-10-07  2019-01-24
#
# [282 rows x 13 columns]

# %%
fillna() replaces the NULL values with a specified value.

# %%
data.fillna(10)
# Out:
#                                                  img  \
# 0      /games/boxart/full_6510540AmericaFrontccc.jpg
# 1      /games/boxart/full_5563178AmericaFrontccc.jpg
# 2                        /games/boxart/827563ccc.jpg
# 3      /games/boxart/full_9218923AmericaFrontccc.jpg
# 4      /games/boxart/full_4990510AmericaFrontccc.jpg
# ...                                              ...
# 64011  /games/boxart/full_2779838AmericaFrontccc.jpg
# 64012  /games/boxart/full_8031506AmericaFrontccc.jpg
# 64013  /games/boxart/full_6553045AmericaFrontccc.jpg
# 64014    /games/boxart/full_6012940JapanFrontccc.png
# 64015                      /games/boxart/default.jpg
#
#                                   title console         genre  \
# 0                    Grand Theft Auto V     PS3        Action
# 1                    Grand Theft Auto V     PS4        Action
# 2           Grand Theft Auto: Vice City     PS2        Action
# 3                    Grand Theft Auto V    X360        Action
# 4             Call of Duty: Black Ops 3     PS4       Shooter
# ...                                 ...     ...           ...
# 64011             XBlaze Lost: Memories      PC  Visual Novel
# 64012                      Yoru, Tomosu     PS4  Visual Novel
# 64013                      Yoru, Tomosu      NS  Visual Novel
# 64014   Yunohana SpRING! ~Mellow Times~      NS  Visual Novel
# 64015  Yurukill: The Calumniation Games     PS4  Visual Novel
#
#                   publisher             developer  critic_score  na_sales  \
# 0            Rockstar Games        Rockstar North           9.4      6.37
# 1            Rockstar Games        Rockstar North           9.7      6.06
# 2            Rockstar Games        Rockstar North           9.6      8.41
# 3            Rockstar Games        Rockstar North          10.0      9.06
# 4                Activision              Treyarch           8.1      6.18
# ...                     ...                   ...           ...       ...
# 64011           Aksys Games      Arc System Works          10.0     10.00
# 64012  Nippon Ichi Software  Nippon Ichi Software          10.0     10.00
# 64013  Nippon Ichi Software  Nippon Ichi Software          10.0     10.00
# 64014          Idea Factory               Otomate          10.0     10.00
# 64015               Unknown            G.rev Ltd.          10.0     10.00
#
#        jp_sales  pal_sales  other_sales release_date last_update
# 0          0.99       9.85         3.12   2013-09-17          10
# 1          0.60       9.71         3.02   2014-11-18  2018-01-03
# 2          0.47       5.49         1.78   2002-10-28          10
# 3          0.06       5.33         1.42   2013-09-17          10
# 4          0.41       6.05         2.44   2015-11-06  2018-01-14
# ...         ...        ...          ...          ...         ...
# 64011     10.00      10.00        10.00   2016-08-11  2019-01-28
# 64012     10.00      10.00        10.00   2020-07-30  2020-05-09
# 64013     10.00      10.00        10.00   2020-07-30  2020-05-09
# 64014     10.00      10.00        10.00   2019-02-28  2019-02-24
# 64015     10.00      10.00        10.00           10  2023-09-29
#
# [64016 rows x 13 columns]

# %%
Creating total_sales column

# %%
cols=['na_sales','jp_sales','pal_sales','other_sales']
data['total_sales']=data[cols].sum(axis=1)

# %%
data
# Out:
#                                                  img  \
# 0      /games/boxart/full_6510540AmericaFrontccc.jpg
# 1      /games/boxart/full_5563178AmericaFrontccc.jpg
# 2                        /games/boxart/827563ccc.jpg
# 3      /games/boxart/full_9218923AmericaFrontccc.jpg
# 4      /games/boxart/full_4990510AmericaFrontccc.jpg
# ...                                              ...
# 64011  /games/boxart/full_2779838AmericaFrontccc.jpg
# 64012  /games/boxart/full_8031506AmericaFrontccc.jpg
# 64013  /games/boxart/full_6553045AmericaFrontccc.jpg
# 64014    /games/boxart/full_6012940JapanFrontccc.png
# 64015                      /games/boxart/default.jpg
#
#                                   title console         genre  \
# 0                    Grand Theft Auto V     PS3        Action
# 1                    Grand Theft Auto V     PS4        Action
# 2           Grand Theft Auto: Vice City     PS2        Action
# 3                    Grand Theft Auto V    X360        Action
# 4             Call of Duty: Black Ops 3     PS4       Shooter
# ...                                 ...     ...           ...
# 64011             XBlaze Lost: Memories      PC  Visual Novel
# 64012                      Yoru, Tomosu     PS4  Visual Novel
# 64013                      Yoru, Tomosu      NS  Visual Novel
# 64014   Yunohana SpRING! ~Mellow Times~      NS  Visual Novel
# 64015  Yurukill: The Calumniation Games     PS4  Visual Novel
#
#                   publisher             developer  critic_score  na_sales  \
# 0            Rockstar Games        Rockstar North           9.4      6.37
# 1            Rockstar Games        Rockstar North           9.7      6.06
# 2            Rockstar Games        Rockstar North           9.6      8.41
# 3            Rockstar Games        Rockstar North           NaN      9.06
# 4                Activision              Treyarch           8.1      6.18
# ...                     ...                   ...           ...       ...
# 64011           Aksys Games      Arc System Works           NaN       NaN
# 64012  Nippon Ichi Software  Nippon Ichi Software           NaN       NaN
# 64013  Nippon Ichi Software  Nippon Ichi Software           NaN       NaN
# 64014          Idea Factory               Otomate           NaN       NaN
# 64015               Unknown            G.rev Ltd.           NaN       NaN
#
#        jp_sales  pal_sales  other_sales release_date last_update  total_sales
# 0          0.99       9.85         3.12   2013-09-17         NaN        20.33
# 1          0.60       9.71         3.02   2014-11-18  2018-01-03        19.39
# 2          0.47       5.49         1.78   2002-10-28         NaN        16.15
# 3          0.06       5.33         1.42   2013-09-17         NaN        15.87
# 4          0.41       6.05         2.44   2015-11-06  2018-01-14        15.08
# ...         ...        ...          ...          ...         ...          ...
# 64011       NaN        NaN          NaN   2016-08-11  2019-01-28         0.00
# 64012       NaN        NaN          NaN   2020-07-30  2020-05-09         0.00
# 64013       NaN        NaN          NaN   2020-07-30  2020-05-09         0.00
# 64014       NaN        NaN          NaN   2019-02-28  2019-02-24         0.00
# 64015       NaN        NaN          NaN          NaN  2023-09-29         0.00
#
# [64016 rows x 14 columns]

# %%
Computing the mean, median, and standard deviation for total sales

# %%
import numpy as np

# %%
mean_val = np.mean(data['total_sales'])
median_val = np.median(data['total_sales'])
std_val = np.std(data['total_sales'])
print(mean_val)
print(median_val)
print(std_val)
# Out:
# 0.1031212509372657
# 0.0
# 0.4670673936190862

# %%
Filter records based on specific criteria : select rows where a total sales exceeds 13

# %%
filtered_data = data[data['total_sales'] > 13]
filtered_data
# Out:
#                                                   img  \
# 0       /games/boxart/full_6510540AmericaFrontccc.jpg
# 1       /games/boxart/full_5563178AmericaFrontccc.jpg
# 2                         /games/boxart/827563ccc.jpg
# 3       /games/boxart/full_9218923AmericaFrontccc.jpg
# 4       /games/boxart/full_4990510AmericaFrontccc.jpg
# 5   /games/boxart/full_call-of-duty-modern-warfare...
# 6   /games/boxart/full_call-of-duty-black-ops_5Ame...
# 7       /games/boxart/full_4653215AmericaFrontccc.jpg
# 8       /games/boxart/full_1977964AmericaFrontccc.jpg
# 9       /games/boxart/full_4649679AmericaFrontccc.png
# 10       /games/boxart/full_809251AmericaFrontccc.jpg
# 11      /games/boxart/full_4380292AmericaFrontccc.jpg
# 12  /games/boxart/full_call-of-duty-modern-warfare...
# 13                       /games/boxart/3570928ccc.jpg
#
#                              title console             genre       publisher  \
# 0               Grand Theft Auto V     PS3            Action  Rockstar Games
# 1               Grand Theft Auto V     PS4            Action  Rockstar Games
# 2      Grand Theft Auto: Vice City     PS2            Action  Rockstar Games
# 3               Grand Theft Auto V    X360            Action  Rockstar Games
# 4        Call of Duty: Black Ops 3     PS4           Shooter      Activision
# 5   Call of Duty: Modern Warfare 3    X360           Shooter      Activision
# 6          Call of Duty: Black Ops    X360           Shooter      Activision
# 7            Red Dead Redemption 2     PS4  Action-Adventure  Rockstar Games
# 8       Call of Duty: Black Ops II    X360           Shooter      Activision
# 9       Call of Duty: Black Ops II     PS3           Shooter      Activision
# 10  Call of Duty: Modern Warfare 2    X360           Shooter      Activision
# 11              Call of Duty: WWII     PS4           Shooter      Activision
# 12  Call of Duty: Modern Warfare 3     PS3           Shooter      Activision
# 13            Grand Theft Auto III     PS2            Action  Rockstar Games
#
#              developer  critic_score  na_sales  jp_sales  pal_sales  \
# 0       Rockstar North           9.4      6.37      0.99       9.85
# 1       Rockstar North           9.7      6.06      0.60       9.71
# 2       Rockstar North           9.6      8.41      0.47       5.49
# 3       Rockstar North           NaN      9.06      0.06       5.33
# 4             Treyarch           8.1      6.18      0.41       6.05
# 5        Infinity Ward           8.7      9.07      0.13       4.29
# 6             Treyarch           8.8      9.76      0.11       3.73
# 7       Rockstar Games           9.8      5.26      0.21       6.21
# 8             Treyarch           8.4      8.27      0.07       4.32
# 9             Treyarch           8.0      4.99      0.65       5.88
# 10       Infinity Ward           9.5      8.54      0.08       3.63
# 11  Sledgehammer Games           8.1      4.67      0.40       6.21
# 12       Infinity Ward           8.8      5.54      0.49       5.78
# 13          DMA Design           9.5      6.99      0.30       4.51
#
#     other_sales release_date last_update  total_sales
# 0          3.12   2013-09-17         NaN        20.33
# 1          3.02   2014-11-18  2018-01-03        19.39
# 2          1.78   2002-10-28         NaN        16.15
# 3          1.42   2013-09-17         NaN        15.87
# 4          2.44   2015-11-06  2018-01-14        15.08
# 5          1.33   2011-11-08         NaN        14.82
# 6          1.14   2010-11-09         NaN        14.74
# 7          2.26   2018-10-26  2018-11-02        13.94
# 8          1.20   2012-11-13  2018-04-07        13.86
# 9          2.28   2012-11-13  2018-04-07        13.80
# 10         1.28   2009-11-10         NaN        13.53
# 11         2.12   2017-11-03  2017-12-31        13.40
# 12         1.54   2011-11-08         NaN        13.35
# 13         1.30   2001-10-23         NaN        13.10

# %%
Create a histogram to show the distribution of a total_sales

# %%
import matplotlib.pyplot as plt
plt.hist(data['total_sales'], bins=20, color='green')
plt.title('Distribution of Numeric Column')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
Generate a scatter plot to analyze the relationship between two numerical variables

# %%
plt.scatter(data['other_sales'], data['pal_sales'],color='darkblue', alpha=0.2)
plt.title('pal_sales vs other_sales')
plt.xlabel('other_sales')
plt.ylabel('pal_sales')
plt.show()
